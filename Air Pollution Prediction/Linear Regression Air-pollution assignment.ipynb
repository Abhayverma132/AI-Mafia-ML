# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
test_csv=pd.read_csv(r"C:\Users\abhay verma\Downloads\Air Pollution Prediction\Test.csv")
train_csv=pd.read_csv(r"C:\Users\abhay verma\Downloads\Air Pollution Prediction\Train.csv")
print(train_csv,train_csv.shape,type(train_csv),test_csv,test_csv.shape,type(test_csv))
# Out:
#       feature_1  feature_2  feature_3  feature_4  feature_5      target
# 0      0.293416  -0.945599  -0.421105   0.406816   0.525662  -82.154667
# 1     -0.836084  -0.189228  -0.776403  -1.053831   0.597997  -48.897960
# 2      0.236425   0.132836  -0.147723   0.699854  -0.187364   77.270371
# 3      0.175312   0.143194  -0.581111  -0.122107  -1.292168   -2.988581
# 4     -1.693011   0.542712  -2.798729  -0.686723   1.244077  -37.596722
# ...         ...        ...        ...        ...        ...         ...
# 1595  -0.274961  -0.820634  -0.757173  -0.147555  -0.307149  -80.110012
# 1596  -0.076099   0.255257   0.290054   1.796036   0.340350  118.315601
# 1597   1.044177  -0.899206   1.730399  -1.871057   0.442520 -107.510508
# 1598  -1.269173  -0.005052   1.857669  -1.080365   0.736334  -47.341558
# 1599  -1.884000  -0.849427  -1.452270   0.488613   1.459576 -115.939003
#
# ...

# %%
x1=train_csv['feature_1'].values.reshape((-1,1))
x2=train_csv['feature_2'].values.reshape((-1,1))
x3=train_csv['feature_3'].values.reshape((-1,1))
x4=train_csv['feature_4'].values.reshape((-1,1))
x5=train_csv['feature_5'].values.reshape((-1,1))
x=train_csv[['feature_1','feature_2','feature_3','feature_4','feature_5']].values
y=train_csv['target'].values.reshape((-1,1))

# %%
plt.figure(figsize=(10,10))
plt.scatter(x1,y,color="green",label='feature_1')
plt.scatter(x2,y,color="red",label='feature_2')
plt.scatter(x3,y,color="blue",label='feature_3')
plt.scatter(x4,y,color="violet",label='feature_4')
plt.scatter(x5,y,color="yellow",label='feature_5')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
reg=LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
output=reg.predict(x)
output
# Out:
# array([[ -57.87196311],
#        [ -89.46019557],
#        [  53.95305942],
#        ...,
#        [-115.65802541],
#        [ -64.27649688],
#        [-116.11442895]])

# %%
bias=reg.intercept_
coef=reg.coef_
print(bias,coef)
# Out:
# [4.99096674] [[29.68187118 92.66247759  8.28062089 44.76773522  2.51916121]]

# %%
reg.score(x,y)
# Out:
# 0.9660939669975616

# %%
plt.figure(figsize=(10,10))
plt.plot(x,output,label='predictons')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
t1=test_csv['feature_1'].values.reshape((-1,1))
t2=test_csv['feature_2'].values.reshape((-1,1))
t3=test_csv['feature_3'].values.reshape((-1,1))
t4=test_csv['feature_4'].values.reshape((-1,1))
t5=test_csv['feature_5'].values.reshape((-1,1))
t=test_csv[['feature_1','feature_2','feature_3','feature_4','feature_5']].values
print(t,t.shape,type(t),sep='\n')
# Out:
# [[ 1.01525387e+00  2.07620944e+00 -2.66434820e-01 -2.41808820e+00
#   -9.80502790e-01]
#  [-3.75021204e-01  9.53184528e-01  6.26719138e-01  7.04405750e-01
#   -3.55489211e-01]
#  [-1.02445225e+00  9.62991107e-01 -4.07942004e-01 -1.86127383e+00
#    4.55201351e-01]
#  ...
#  [ 5.54727647e-01  1.76824345e+00 -8.97787210e-01 -1.19366107e+00
#    3.40563374e-01]
#  [-1.62717246e+00  8.56470994e-01 -5.65729519e-04  6.29386649e-01
#    4.53382144e-01]
#  [ 1.39310499e-01  5.31597186e-01 -8.53107053e-01  3.16920076e-02
#    1.71489304e+00]]
# (400, 5)
# <class 'numpy.ndarray'>

# %%
testoutput=reg.predict(t)
print(testoutput,testoutput.shape,type(testoutput),sep="\n\n")
# Out:
# [[ 1.14583689e+02]
#  [ 1.18012815e+02]
#  [-2.17398523e+01]
#  [-4.39368985e+01]
#  [-9.59148984e+01]
#  [-4.45074240e+01]
#  [-7.55665260e+01]
#  [ 2.38208355e+01]
#  [ 1.73835284e+02]
#  [ 1.72849290e+02]
#  [-1.05402312e+02]
#  [-2.08020234e+01]
#  [-3.91323777e+00]
#  [ 1.22999186e+02]
#  [ 4.03078842e+01]
#  [ 4.57128495e+01]
#  [-1.89628491e+02]
#  [ 2.26125454e+01]
#  [ 1.16410473e+01]
#  [ 1.36342143e+02]
#  [ 6.49162552e+01]
#  [-6.19884884e+01]
#  [-1.08194679e+02]
#  [-7.41212747e+00]
#  [-5.85239528e+01]
#  [ 1.18889777e+01]
#  [ 2.92376400e+01]
#  [ 1.07687579e+02]
#  [ 2.41468563e+01]
#  [-2.61050120e+01]
#  [ 1.10968076e+02]
#  [-4.48797096e+01]
#  [ 2.16799939e+02]
#  [-1.38606052e+01]
#  [-2.28603182e+02]
#  [ 1.54896021e+02]
#  [-2.22583390e+00]
#  [ 1.27230344e+01]
#  [-3.08307877e+02]
#  [ 7.71107583e+01]
#  [-8.12079177e+01]
#  [-2.06632925e+02]
#  [-2.38762881e+02]
#  [ 1.34757365e+02]
#  [-7.37514777e+01]
#  [ 1.05463702e+02]
#  [-3.59074927e+00]
# ...

# %%
plt.figure(figsize=(10,6))
plt.scatter(t1,testoutput,color="red",label='feature_1')
plt.scatter(t2,testoutput,color="green",label='feature_2')
plt.scatter(t3,testoutput,color="black",label='feature_3')
plt.scatter(t4,testoutput,color="blue",label='feature_4')
plt.scatter(t5,testoutput,color="violet",label='feature_5')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
plt.close()

# %%
plt.figure(figsize=(10,8))
plt.plot(t,testoutput,label='predictons')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
out=test_csv
out['predicted target']=testoutput
out
# Out:
#      feature_1  feature_2  feature_3  feature_4  feature_5  predicted target
# 0     1.015254   2.076209  -0.266435  -2.418088  -0.980503        114.583689
# 1    -0.375021   0.953185   0.626719   0.704406  -0.355489        118.012815
# 2    -1.024452   0.962991  -0.407942  -1.861274   0.455201        -21.739852
# 3    -2.489841   0.544802   0.601219  -0.607021  -1.314286        -43.936899
# 4    -0.384675  -0.833624   1.358552  -0.547932   0.411925        -95.914898
# ..         ...        ...        ...        ...        ...               ...
# 395  -0.436959  -0.575844  -1.620908  -0.222588   1.086013        -81.989000
# 396  -0.421324  -2.417543   0.876275   0.844565   0.171646       -186.032535
# 397   0.554728   1.768243  -0.897787  -1.193661   0.340563        125.292336
# 398  -1.627172   0.856471  -0.000566   0.629387   0.453382         65.369841
# 399   0.139310   0.531597  -0.853107   0.031692   1.714893         57.059691
#
# [400 rows x 6 columns]

# %%
out.to_csv('Test.csv',index=False,header=True)
